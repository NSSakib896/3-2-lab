# %%
import numpy as np
from scipy.signal import firwin,freqz
import matplotlib.pyplot as plt

# %%
pass_band = 2000
stop = 5000
fs1 = 20000
filter_length = 21

# %%
tap = firwin(filter_length, pass_band,width=stop-pass_band,pass_zero='lowpass',fs=fs1,window='hann')

response = freqz(tap, worN=8000)

# %%
plt.plot(fs1*.5*response[0]/(np.pi), np.abs(response[1]))
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as signal

# %%
pass_band = [1500,3000]
tran_width = 500
fs = 10000
filter_length = 67

# %%
taps = signal.firwin(67,pass_band,fs=fs,pass_zero='bandpass',window='blackman',width=tran_width)
response = signal.freqz(taps,worN=8000)

# %%
plt.plot(fs*response[0]/2/np.pi,np.abs(response[1]))
plt.grid()

# %%
response
# Out:
# (array([0.00000000e+00, 3.92699082e-04, 7.85398163e-04, ...,
#         3.14041456e+00, 3.14080726e+00, 3.14119995e+00]),
#  array([0.00021544+0.00000000e+00j, 0.0002154 -2.79157268e-06j,
#         0.00021529-5.58105370e-06j, ..., 0.00017675+6.87492845e-06j,
#         0.0001769 +4.58584856e-06j, 0.00017699+2.29369336e-06j]))
